# %%
import numpy as np
import spike_data_augmentation
import spike_data_augmentation.transforms as transforms
from tqdm.auto import tqdm

# %% [markdown]
# ## Average time surfaces

# %%
average_timesurface = transforms.Compose([transforms.ToAveragedTimesurface(merge_polarities=True)])
test_set = spike_data_augmentation.datasets.POKERDVS(save_to='./data', train=False, transform=average_timesurface, download=False)
dataloader = spike_data_augmentation.datasets.Dataloader(test_set, shuffle=False)

# %% [markdown]
# average timesurfaces for single recording

# %%
surfaces, target = next(dataloader)

# %% [markdown]
# Display Average time surfaces

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(20,20, figsize=(8,8))

for i,ax in enumerate(axes.flat):
    ax.imshow(surfaces[i][0])
    ax.axis('off')

# %% [markdown]
# ## Time Surfaces

# %%
timesurface = transforms.Compose([transforms.ToTimesurface(merge_polarities=True)])
test_set = spike_data_augmentation.datasets.POKERDVS(save_to='./data', train=False, transform=timesurface, download=False)
dataloader = spike_data_augmentation.datasets.Dataloader(test_set, shuffle=False)

# %% [markdown]
# timesurfaces for single recording

# %%
surfaces, target = next(dataloader)

# %% [markdown]
# Display time surfaces

# %%
fig, axes = plt.subplots(20,20, figsize=(8,8))

for i,ax in enumerate(axes.flat):
    ax.imshow(surfaces[i][0])
    ax.axis('off')
